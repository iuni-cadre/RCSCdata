// %%
import org.apache.spark.sql.{SQLContext, SaveMode}
import org.apache.spark.sql.types.{StructType, StructField, StringType, DoubleType};
import com.databricks.spark.xml._

val sqlContext = new SQLContext(sc)
import sqlContext.implicits._
sqlContext.sql("set spark.sql.caseSensitive=true") 

//sc.hadoopConfiguration.set("fs.s3a.access.key", "AKIAJBXFDKLW67XRX5IA");
//sc.hadoopConfiguration.set("fs.s3a.secret.key", "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");
spark.sparkContext.uiWebUrl
// Out:
// Waiting for a Spark session to start...
// sqlContext = org.apache.spark.sql.SQLContext@41fcccb4
// warning: there was one deprecation warning; re-run with -deprecation for details
// Some(http://iuni2:4041)

// %%
val WoS = spark.read.format("parquet").load("/WoSraw/parquet/*.parquet")

val WoS2 = WoS.select("UID","static_data.summary.titles","static_data.fullrecord_metadata.category_info")
WoS2.printSchema
// Out:
// root
//  |-- UID: string (nullable = true)
//  |-- titles: struct (nullable = true)
//  |    |-- _count: long (nullable = true)
//  |    |-- title: array (nullable = true)
//  |    |    |-- element: struct (containsNull = true)
//  |    |    |    |-- _VALUE: string (nullable = true)
//  |    |    |    |-- _translated: string (nullable = true)
//  |    |    |    |-- _type: string (nullable = true)
//  |-- category_info: struct (nullable = true)
//  |    |-- headings: struct (nullable = true)
//  |    |    |-- _count: long (nullable = true)
//  |    |    |-- heading: array (nullable = true)
//  |    |    |    |-- element: string (containsNull = true)
//  |    |-- subheadings: struct (nullable = true)
//  |    |    |-- _count: long (nullable = true)
//  |    |    |-- subheading: array (nullable = true)
//  |    |    |    |-- element: string (containsNull = true)
//  |    |-- subjects: struct (nullable = true)
//  |    |    |-- _count: long (nullable = true)
//  |    |    |-- subject: array (nullable = true)
//  |    |    |    |-- element: struct (containsNull = true)
//  |    |    |    |    |-- _VALUE: string (nullable = true)
//  |    |    |    |    |-- _ascatype: string (nullable = true)
// WoS = [UID: string, _r_id_disclaimer: string ... 13 more fields]
// WoS2 = [UID: string, titles: struct<_count: bigint, title: array<struct<_VALUE:string,_translated:string,_type:string>>> ... 1 more field]
// [UID: string, titles: struct<_count: bigint, title: array<struct<_VALUE:string,_translated:string,_type:string>>> ... 1 more field]

// %%
import scala.util.Try
import org.apache.hadoop.fs._
import org.apache.spark.sql.Row

def getTitle(_type: String) = { 
  udf((row: Seq[Row]) =>
    row.map(r => (r.getString(0), r.getString(1), r.getString(2)))
      .find { case (_, _, s) => s == _type}
      .map(_._1)
      .orElse(None)
  )
}

val WoS3 = WoS2.withColumn("journal", when(col("titles.title").isNotNull, getTitle("source")($"titles.title")).otherwise(lit(null)))
        .select("UID","journal","category_info.headings.heading","category_info.subheadings.subheading","category_info.subjects.subject").cache()
WoS3.show(false)
// Out:
// +-------------------+-------------------------------------------------------+----------------------+------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
// |UID                |journal                                                |heading               |subheading                                      |subject                                                                                                                                                                               |
// +-------------------+-------------------------------------------------------+----------------------+------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
// |WOS:A1985AQZ3200328|IEEE TRANSACTIONS ON BIOMEDICAL ENGINEERING            |[Science & Technology]|[Technology]                                    |[[Engineering, Biomedical, traditional], [Engineering, extended]]                                                                                                                     |
// |WOS:A1985ACW7200011|HUMAN SYSTEMS MANAGEMENT                               |[Social Sciences]     |null                                            |[[Management, traditional], [Business & Economics, extended]]                                                                                                                         |
// |WOS:A1985AWJ5900008|MOKUZAI GAKKAISHI                                      |[Science & Technology]|[Technology]                                    |[[Materials Science, Paper & Wood, traditional], [Materials Science, extended]]                                                                                                       |
// |WOS:A1985AVS3400010|STUDIA PSYCHOLOGICA                                    |[Social Sciences]     |null                                            |[[Psychology, Multidisciplinary, traditional], [Psychology, extended]]                                                                                                                |
// |WOS:A1985AYJ3100008|PSYCHOLOGY OF WOMEN QUARTERLY                          |[Social Sciences]     |null                                            |[[Psychology, Multidisciplinary, traditional], [Women's Studies, traditional], [Psychology, extended], [Women's Studies, extended]]                                                   |
// |WOS:A1985ASV9200016|INTERNATIONAL JOURNAL OF SYSTEMATIC BACTERIOLOGY       |[Science & Technology]|[Life Sciences & Biomedicine]                   |[[Microbiology, traditional], [Microbiology, extended]]                                                                                                                               |
// |WOS:A1985ATS6500007|JOURNAL OF TESTING AND EVALUATION                      |[Science & Technology]|[Technology]                                    |[[Materials Science, Characterization & Testing, traditional], [Materials Science, extended]]                                                                                         |
// |WOS:A1985AEV2400004|AMERICAN HEART JOURNAL                                 |[Science & Technology]|[Life Sciences & Biomedicine]                   |[[Cardiac & Cardiovascular Systems, traditional], [Cardiovascular System & Cardiology, extended]]                                                                                     |
// |WOS:A1985AHT6800018|JOURNAL OF CHEMICAL PHYSICS                            |[Science & Technology]|[Physical Sciences]                             |[[Chemistry, Physical, traditional], [Physics, Atomic, Molecular & Chemical, traditional], [Chemistry, extended], [Physics, extended]]                                                |
// |WOS:A1985ASV0800026|TRANSACTIONS OF THE IRON AND STEEL INSTITUTE OF JAPAN  |[Science & Technology]|[Technology]                                    |[[Metallurgy & Metallurgical Engineering, traditional], [Metallurgy & Metallurgical Engineering, extended]]                                                                           |
// |WOS:A1985AKJ6800035|PHARMAZIE                                              |[Science & Technology]|[Life Sciences & Biomedicine, Physical Sciences]|[[Chemistry, Medicinal, traditional], [Chemistry, Multidisciplinary, traditional], [Pharmacology & Pharmacy, traditional], [Pharmacology & Pharmacy, extended], [Chemistry, extended]]|
// |WOS:A1985AML0300003|ANNALS OF THE NEW YORK ACADEMY OF SCIENCES             |[Science & Technology]|null                                            |[[Multidisciplinary Sciences, traditional], [Science & Technology - Other Topics, extended]]                                                                                          |
// |WOS:A1985ACE8400007|PRAXIS DER PSYCHOTHERAPIE UND PSYCHOSOMATIK            |[Science & Technology]|[Life Sciences & Biomedicine]                   |[[Psychiatry, traditional], [Psychiatry, extended]]                                                                                                                                   |
// |WOS:A1985ARH5000071|HEPATOLOGY                                             |[Science & Technology]|[Life Sciences & Biomedicine]                   |[[Gastroenterology & Hepatology, traditional], [Gastroenterology & Hepatology, extended]]                                                                                             |
// |WOS:A1985ASE4800021|JOURNAL OF GEOPHYSICAL RESEARCH-SOLID EARTH AND PLANETS|[Science & Technology]|[Physical Sciences]                             |[[Geosciences, Multidisciplinary, traditional], [Geology, extended]]                                                                                                                  |
// |WOS:A1985AMB0500025|SHAKESPEARE QUARTERLY                                  |[Arts & Humanities]   |null                                            |[[Literature, British Isles, traditional], [Theater, traditional], [Literature, extended], [Theater, extended]]                                                                       |
// |WOS:A1985AYV8600004|ACTA HISTOCHEMICA                                      |[Science & Technology]|[Life Sciences & Biomedicine]                   |[[Cell Biology, traditional], [Cell Biology, extended]]                                                                                                                               |
// |WOS:A1985AWL4800024|SCANDINAVIAN JOURNAL OF UROLOGY AND NEPHROLOGY         |[Science & Technology]|[Life Sciences & Biomedicine]                   |[[Urology & Nephrology, traditional], [Urology & Nephrology, extended]]                                                                                                               |
// |WOS:A1985AQB3200012|MONTHLY WEATHER REVIEW                                 |[Science & Technology]|[Physical Sciences]                             |[[Meteorology & Atmospheric Sciences, traditional], [Meteorology & Atmospheric Sciences, extended]]                                                                                   |
// |WOS:A1985AVV2400003|REVUE DU PRATICIEN                                     |[Science & Technology]|[Life Sciences & Biomedicine]                   |[[Medicine, General & Internal, traditional], [General & Internal Medicine, extended]]                                                                                                |
// +-------------------+-------------------------------------------------------+----------------------+------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
// only showing top 20 rows
// WoS3 = [UID: string, journal: string ... 3 more fields]
// getTitle: (_type: String)org.apache.spark.sql.expressions.UserDefinedFunction
// [UID: string, journal: string ... 3 more fields]

// %%
import scala.util.Try
import org.apache.spark.sql.functions._
import org.apache.spark.sql.{Row, SQLContext}
import org.apache.spark.sql.functions.countDistinct
import org.apache.spark.sql.SaveMode

val session = SparkSession.builder().getOrCreate()

session.conf.set(
    "fs.azure.account.key.iunimag.blob.core.windows.net",
    "7lgXqx3QIq4tgEhlHUjoNaEeXYdSUdJkjTHAfurEm7D3CjG1xJWLA6zJle4vW2uM/bZ+W4lwDJaElmCx/14sAg=="
)
val sdf = session.read.csv(
    "wasbs://mag-2020-05-13@iunimag.blob.core.windows.net/CORD-19-research-challenge/metadata.csv"
)
sdf.describe().filter($"summary" === "count").show
// Out:
// +-------+------+-----+------+------+------+-----+-----+------+------+------+------+------+----+-----+----+-----+-----+-----+------+
// |summary|   _c0|  _c1|   _c2|   _c3|   _c4|  _c5|  _c6|   _c7|   _c8|   _c9|  _c10|  _c11|_c12| _c13|_c14| _c15| _c16| _c17|  _c18|
// +-------+------+-----+------+------+------+-----+-----+------+------+------+------+------+----+-----+----+-----+-----+-----+------+
// |  count|128493|55752|128493|128465|100618|60821|99096|128454|101644|128449|123735|122411|2627|19011|3407|57316|45319|50370|101705|
// +-------+------+-----+------+------+------+-----+-----+------+------+------+------+------+----+-----+----+-----+-----+-----+------+
// session = org.apache.spark.sql.SparkSession@49709749
// sdf = [_c0: string, _c1: string ... 17 more fields]
// lastException: Throwable = null
// [_c0: string, _c1: string ... 17 more fields]

// %%
val papers = sdf.join(WoS3, sdf("_c0")===WoS3("UID"), "inner").cache()
papers.describe().filter($"summary" === "count").show
// Out:
// +-------+-------+-------+-------+
// |summary|    _c0|    UID|journal|
// +-------+-------+-------+-------+
// |  count|9686604|9686604|9686604|
// +-------+-------+-------+-------+
// papers = [_c0: string, UID: string ... 4 more fields]
// [_c0: string, UID: string ... 4 more fields]

// %%
papers.printSchema
// Out:
// root
//  |-- _c0: string (nullable = true)
//  |-- UID: string (nullable = true)
//  |-- journal: string (nullable = true)
//  |-- heading: array (nullable = true)
//  |    |-- element: string (containsNull = true)
//  |-- subheading: array (nullable = true)
//  |    |-- element: string (containsNull = true)
//  |-- subject: array (nullable = true)
//  |    |-- element: struct (containsNull = true)
//  |    |    |-- _VALUE: string (nullable = true)
//  |    |    |-- _ascatype: string (nullable = true)

// %%
def getSubject(_type: String) = { 
  udf((row: Seq[Row]) =>
    row.map(r => (r.getString(0), r.getString(1)))
      .find { case (_, s) => s == _type}
      .map(_._1)
      .orElse(None)
  )
}

val papers2 = papers.withColumn("headings", array_join($"heading", ","))
                .withColumn("subheadings", array_join($"subheading", ","))
                //.withColumn("WC/SC", array_join($"subject", ";"))
                .withColumn("WC", when(col("subject").isNotNull, getSubject("traditional")($"subject")).otherwise(lit(null)))
                .withColumn("SC", when(col("subject").isNotNull, getSubject("extended")($"subject")).otherwise(lit(null)))
papers2.show(false)
// Out:
// +-------------------+-------------------+---------------------------------------------------------+----------------------+------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+---------------------------------------------+-------------------------------------------+-------------------------------------------+
// |_c0                |UID                |journal                                                  |heading               |subheading                                      |subject                                                                                                                                                                                                                                                        |headings            |subheadings                                  |WC                                         |SC                                         |
// +-------------------+-------------------+---------------------------------------------------------+----------------------+------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+---------------------------------------------+-------------------------------------------+-------------------------------------------+
// |WOS:000208163700005|WOS:000208163700005|CHEMICAL INDUSTRY & CHEMICAL ENGINEERING QUARTERLY       |[Science & Technology]|[Physical Sciences, Technology]                 |[[Chemistry, Applied, traditional], [Engineering, Chemical, traditional], [Chemistry, extended], [Engineering, extended]]                                                                                                                                      |Science & Technology|Physical Sciences,Technology                 |Chemistry, Applied                         |Chemistry                                  |
// |WOS:000208167100007|WOS:000208167100007|ACM TRANSACTIONS ON RECONFIGURABLE TECHNOLOGY AND SYSTEMS|[Science & Technology]|[Technology]                                    |[[Computer Science, Hardware & Architecture, traditional], [Computer Science, extended]]                                                                                                                                                                       |Science & Technology|Technology                                   |Computer Science, Hardware & Architecture  |Computer Science                           |
// |WOS:000208167200005|WOS:000208167200005|ACM TRANSACTIONS ON RECONFIGURABLE TECHNOLOGY AND SYSTEMS|[Science & Technology]|[Technology]                                    |[[Computer Science, Hardware & Architecture, traditional], [Computer Science, extended]]                                                                                                                                                                       |Science & Technology|Technology                                   |Computer Science, Hardware & Architecture  |Computer Science                           |
// |WOS:000208169900005|WOS:000208169900005|ACM TRANSACTIONS ON KNOWLEDGE DISCOVERY FROM DATA        |[Science & Technology]|[Technology]                                    |[[Computer Science, Information Systems, traditional], [Computer Science, Software Engineering, traditional], [Computer Science, extended]]                                                                                                                    |Science & Technology|Technology                                   |Computer Science, Information Systems      |Computer Science                           |
// |WOS:000208174000005|WOS:000208174000005|INFORMATION TECHNOLOGY FOR DEVELOPMENT                   |[Science & Technology]|[Technology]                                    |[[Information Science & Library Science, traditional], [Information Science & Library Science, extended]]                                                                                                                                                      |Science & Technology|Technology                                   |Information Science & Library Science      |Information Science & Library Science      |
// |WOS:000208188500007|WOS:000208188500007|ENGLISH STUDIES IN CANADA                                |[Arts & Humanities]   |null                                            |[[Literature, traditional], [Literature, extended]]                                                                                                                                                                                                            |Arts & Humanities   |null                                         |Literature                                 |Literature                                 |
// |WOS:000208195000004|WOS:000208195000004|JOURNAL OF BASIC MICROBIOLOGY                            |[Science & Technology]|[Life Sciences & Biomedicine]                   |[[Microbiology, traditional], [Microbiology, extended]]                                                                                                                                                                                                        |Science & Technology|Life Sciences & Biomedicine                  |Microbiology                               |Microbiology                               |
// |WOS:000208208100023|WOS:000208208100023|BIOMEDICAL OPTICS EXPRESS                                |[Science & Technology]|[Life Sciences & Biomedicine, Physical Sciences]|[[Biochemical Research Methods, traditional], [Optics, traditional], [Radiology, Nuclear Medicine & Medical Imaging, traditional], [Biochemistry & Molecular Biology, extended], [Optics, extended], [Radiology, Nuclear Medicine & Medical Imaging, extended]]|Science & Technology|Life Sciences & Biomedicine,Physical Sciences|Biochemical Research Methods               |Biochemistry & Molecular Biology           |
// |WOS:000208209300005|WOS:000208209300005|BIOMEDICAL OPTICS EXPRESS                                |[Science & Technology]|[Life Sciences & Biomedicine, Physical Sciences]|[[Biochemical Research Methods, traditional], [Optics, traditional], [Radiology, Nuclear Medicine & Medical Imaging, traditional], [Biochemistry & Molecular Biology, extended], [Optics, extended], [Radiology, Nuclear Medicine & Medical Imaging, extended]]|Science & Technology|Life Sciences & Biomedicine,Physical Sciences|Biochemical Research Methods               |Biochemistry & Molecular Biology           |
// |WOS:000208216700010|WOS:000208216700010|INTERNATIONAL JOURNAL OF HYGIENE AND ENVIRONMENTAL HEALTH|[Science & Technology]|[Life Sciences & Biomedicine]                   |[[Public, Environmental & Occupational Health, traditional], [Infectious Diseases, traditional], [Public, Environmental & Occupational Health, extended], [Infectious Diseases, extended]]                                                                     |Science & Technology|Life Sciences & Biomedicine                  |Public, Environmental & Occupational Health|Public, Environmental & Occupational Health|
// |WOS:000208217400003|WOS:000208217400003|REVIEW OF FAITH & INTERNATIONAL AFFAIRS                  |[Arts & Humanities]   |null                                            |[[Religion, traditional], [Religion, extended]]                                                                                                                                                                                                                |Arts & Humanities   |null                                         |Religion                                   |Religion                                   |
// |WOS:000208222700010|WOS:000208222700010|JOURNAL OF AGROMEDICINE                                  |[Science & Technology]|[Life Sciences & Biomedicine]                   |[[Public, Environmental & Occupational Health, traditional], [Public, Environmental & Occupational Health, extended]]                                                                                                                                          |Science & Technology|Life Sciences & Biomedicine                  |Public, Environmental & Occupational Health|Public, Environmental & Occupational Health|
// |WOS:000208229400003|WOS:000208229400003|IRANIAN JOURNAL OF ALLERGY ASTHMA AND IMMUNOLOGY         |[Science & Technology]|[Life Sciences & Biomedicine]                   |[[Allergy, traditional], [Immunology, traditional], [Allergy, extended], [Immunology, extended]]                                                                                                                                                               |Science & Technology|Life Sciences & Biomedicine                  |Allergy                                    |Allergy                                    |
// |WOS:000208229600004|WOS:000208229600004|FOLK LIFE                                                |[Arts & Humanities]   |null                                            |[[Folklore, traditional], [Arts & Humanities - Other Topics, extended]]                                                                                                                                                                                        |Arts & Humanities   |null                                         |Folklore                                   |Arts & Humanities - Other Topics           |
// |WOS:000208252100013|WOS:000208252100013|JOURNAL OF INFECTION IN DEVELOPING COUNTRIES             |null                  |null                                            |null                                                                                                                                                                                                                                                           |null                |null                                         |null                                       |null                                       |
// |WOS:000208279300010|WOS:000208279300010|ZEITSCHRIFT FUR DIE ALTTESTAMENTLICHE WISSENSCHAFT       |[Arts & Humanities]   |null                                            |[[Religion, traditional], [Religion, extended]]                                                                                                                                                                                                                |Arts & Humanities   |null                                         |Religion                                   |Religion                                   |
// |WOS:000208283400009|WOS:000208283400009|JOURNAL OF STROKE & CEREBROVASCULAR DISEASES             |[Science & Technology]|[Life Sciences & Biomedicine]                   |[[Neurosciences, traditional], [Peripheral Vascular Disease, traditional], [Neurosciences & Neurology, extended], [Cardiovascular System & Cardiology, extended]]                                                                                              |Science & Technology|Life Sciences & Biomedicine                  |Neurosciences                              |Neurosciences & Neurology                  |
// |WOS:000208313900001|WOS:000208313900001|ADVANCES IN MECHANICAL ENGINEERING                       |[Science & Technology]|[Physical Sciences, Technology]                 |[[Thermodynamics, traditional], [Engineering, Mechanical, traditional], [Thermodynamics, extended], [Engineering, extended]]                                                                                                                                   |Science & Technology|Physical Sciences,Technology                 |Thermodynamics                             |Thermodynamics                             |
// |WOS:000208316700017|WOS:000208316700017|STRUCTURAL ENGINEERING INTERNATIONAL                     |[Science & Technology]|[Technology]                                    |[[Construction & Building Technology, traditional], [Engineering, Civil, traditional], [Construction & Building Technology, extended], [Engineering, extended]]                                                                                                |Science & Technology|Technology                                   |Construction & Building Technology         |Construction & Building Technology         |
// |WOS:000208326700004|WOS:000208326700004|TRANSLATIONAL STROKE RESEARCH                            |[Science & Technology]|[Life Sciences & Biomedicine]                   |[[Clinical Neurology, traditional], [Neurosciences, traditional], [Neurosciences & Neurology, extended]]                                                                                                                                                       |Science & Technology|Life Sciences & Biomedicine                  |Clinical Neurology                         |Neurosciences & Neurology                  |
// +-------------------+-------------------+---------------------------------------------------------+----------------------+------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+---------------------------------------------+-------------------------------------------+-------------------------------------------+
// only showing top 20 rows
// papers2 = [_c0: string, UID: string ... 8 more fields]
// getSubject: (_type: String)org.apache.spark.sql.expressions.UserDefinedFunction
// [_c0: string, UID: string ... 8 more fields]

// %%
val journalMap = spark.read.format("csv").option("header", true).load("wasbs://mag-2020-02-14@iunimag.blob.core.windows.net/journalName.csv")
                .filter($"source_type" === "Thomson")
//journalMap.show
val papers3 = papers2.join(journalMap, regexp_replace(papers2("journal"),"\\s", "")
                           ===regexp_replace(journalMap("journal_name"),"\\s", ""), "left").cache()
papers3.describe().filter($"summary" === "count").show
// Out:
// +-------+-------+-------+-------+--------+-----------+-------+-------+--------+------------+-----------+
// |summary|    _c0|    UID|journal|headings|subheadings|     WC|     SC|journ_id|journal_name|source_type|
// +-------+-------+-------+-------+--------+-----------+-------+-------+--------+------------+-----------+
// |  count|9686604|9686604|9686604| 9584480|    8030289|9584480|9584480| 6369116|     6369116|    6369116|
// +-------+-------+-------+-------+--------+-----------+-------+-------+--------+------------+-----------+
// journalMap = [journ_id: string, journal_name: string ... 1 more field]
// papers3 = [_c0: string, UID: string ... 11 more fields]
// [_c0: string, UID: string ... 11 more fields]

// %%
//JsubMap = pd.read_csv('WoSmatch/jounral-subdiscipline.csv')
//JsubMap.journ_id = JsubMap.journ_id.astype('float64')
//subMatched = pd.merge(MAGmatched, JsubMap, left_on=['journ_id'], right_on=['journ_id'], how='left').drop(columns='formal_name')
val JsubMap = spark.read.format("csv").option("header", true).load("wasbs://mag-2020-02-14@iunimag.blob.core.windows.net/jounral-subdiscipline.csv")
val papers4 = papers3.join(JsubMap, papers3("journ_id")===JsubMap("journ_id"), "left")
papers4.describe().filter($"summary" === "count").show
// Out:
// +-------+--------+--------+--------+--------+-----------+--------+--------+--------+------------+-----------+--------+-----------+---------+-------+
// |summary|     _c0|     UID| journal|headings|subheadings|      WC|      SC|journ_id|journal_name|source_type|journ_id|formal_name|jfraction|subd_id|
// +-------+--------+--------+--------+--------+-----------+--------+--------+--------+------------+-----------+--------+-----------+---------+-------+
// |  count|12487170|12487170|12487170|12379214|    9299751|12379214|12379214| 9169682|     9169682|    9169682| 9169682|    9169682|  9169682|9169682|
// +-------+--------+--------+--------+--------+-----------+--------+--------+--------+------------+-----------+--------+-----------+---------+-------+
// JsubMap = [journ_id: string, formal_name: string ... 2 more fields]
// papers4 = [_c0: string, UID: string ... 15 more fields]
// [_c0: string, UID: string ... 15 more fields]

// %%
val subList = spark.read.format("csv").option("header", true).load("wasbs://mag-2020-02-14@iunimag.blob.core.windows.net/subdiscipline.csv")
//subList.show
val papers5 = papers4.join(subList, papers4("subd_id")===subList("subd_id"), "left")

val discList = spark.read.format("csv").option("header", true).load("wasbs://mag-2020-02-14@iunimag.blob.core.windows.net/discipline.csv")
val papers6 = papers5.join(discList, papers5("disc_id")===discList("disc_id"), "left").cache()
papers6.describe().filter($"summary" === "count").show
// Out:
// +-------+--------+--------+--------+--------+-----------+--------+--------+--------+------------+-----------+--------+-----------+---------+-------+-------+---------+-------+-------+-------+-------+-------+---------+-------+-------+-------+
// |summary|     _c0|     UID| journal|headings|subheadings|      WC|      SC|journ_id|journal_name|source_type|journ_id|formal_name|jfraction|subd_id|subd_id|subd_name|disc_id|      x|      y|   size|disc_id|disc_name|      x|      y|  color|
// +-------+--------+--------+--------+--------+-----------+--------+--------+--------+------------+-----------+--------+-----------+---------+-------+-------+---------+-------+-------+-------+-------+-------+---------+-------+-------+-------+
// |  count|12487170|12487170|12487170|12379214|    9299751|12379214|12379214| 9169682|     9169682|    9169682| 9169682|    9169682|  9169682|9169682|9169682|  9169682|9169682|9169682|9169682|9169682|9169682|  9169682|9169682|9169682|9169682|
// +-------+--------+--------+--------+--------+-----------+--------+--------+--------+------------+-----------+--------+-----------+---------+-------+-------+---------+-------+-------+-------+-------+-------+---------+-------+-------+-------+
// subList = [subd_id: string, subd_name: string ... 4 more fields]
// papers5 = [_c0: string, UID: string ... 21 more fields]
// discList = [disc_id: string, disc_name: string ... 3 more fields]
// papers6 = [_c0: string, UID: string ... 26 more fields]
// [_c0: string, UID: string ... 26 more fields]

// %%
val UCSDmap = papers6.groupBy("UID").agg(concat_ws(",", collect_list("disc_name")) as "disciplines",
                concat_ws(",", collect_list("subd_name")) as "subdisciplines",
                concat_ws(",", collect_list("jfraction")) as "fractions")
                .toDF("wosid","disciplines","subdisciplines","fractions")
UCSDmap.withColumn("jLength", length(col("fractions"))).orderBy($"jLength".desc).show(60,false)
// Out:
// +-------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
// |wosid              |disciplines                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |subdisciplines                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |fractions                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |jLength|
// +-------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
// |WOS:000311390600043|Biology,Math & Physics,Biology,Infectious Diseases,Earth Sciences,Infectious Diseases,Biology,Medical Specialties,Infectious Diseases,Medical Specialties,Biology,Medical Specialties,Chemistry,Biotechnology,Math & Physics,Math & Physics,Biology,Infectious Diseases,Chemistry,Earth Sciences,Health Professionals,Biology,Medical Specialties,Earth Sciences,Medical Specialties,Biotechnology,Biology,Biology,Medical Specialties,Chemistry,Biology,Chemistry,Math & Physics,Earth Sciences,Chemistry,Earth Sciences,Earth Sciences,Brain Research,Brain Research,Medical Specialties,Biology,Biotechnology,Math & Physics,Health Professionals,Math & Physics,Medical Specialties,Medical Specialties,Earth Sciences,Medical Specialties,Earth Sciences,Brain Research,Brain Research,Earth Sciences,Infectious Diseases,Chemistry,Infectious Diseases,Electrical Engineering & Computer Science,Medical Specialties,Health Professionals,Brain Research,Chemistry,Chemistry,Medical Specialties,Medical Specialties,Biology,Infectious Diseases,Medical Specialties,Medical Specialties,Chemical, Mechanical, & Civil Engineering,Biology,Infectious Diseases,Medical Specialties,Chemistry,Medical Specialties,Health Professionals,Math & Physics,Medical Specialties,Chemistry,Infectious Diseases,Brain Research,Biotechnology,Medical Specialties|Marine Pollution,Physics; Current Developments,Insect Physiology,Sexually Transmitted Diseases,Paleogeography,Cytogenetics & Genome Mapping,Molecular Ecology,Drug Safety,Gene Therapy,Gut,Applied Genetics,Eye,Surfactants,Microbiology Biotechnology,Geophysical Science,Space Research,Human Evolution,Mutation; DNA Repair,Chemistry & Material Science,Climatology,Applied Physiology; Muscle,Molecular Biochemical Parasitology,Molecular Endocrinology,Atmospheric GeoPhysics,Diabetes Metabolism,Proteomics,Molecular Biological Evolution,Ecology,Radiation Protection,Nanotechnology,Comparative Animal Physiology,Molecular Physics,Optics & Lasers,Quaternary Research,Electro Analytical Chemistry,GeoChemistry,Geology & Tectonics,Psychosis; Schizophrenia,Vision,Stem Cells,Pest Management Science,Genomics & Nucleic Acids,High Energy Physics,Drug Discovery,Astronomy & Astrophysics,Clinical Endocrinology,Human Molecular Genetics,Paleobiology,Cardiovascular,Oceanography,Psychopharmacology,Neurology,Seismology,AntiMicrobial Agents,Pharmaceutical Design,Molecular Cell Biology,Applied Optics,Fertility,Nutrition,Clinical Neurophysiology,Pharmaceutical Research,Inorganic Chemistry,Toxicology Applied Pharmacology,Developmental Biology,Marine Biology,Bacteriology,Pharmacology Science,Kidney,Material Science,Plant Physiology,Virology,Leukemia,Organic Chemistry,Rheumatology,Hospital Financial Management,Surface Science,Oncology,Macromolecules & Polymers,Immunology,Neuroscience; Molecular & Cellular,Protein Science,Clinical Cancer Research|0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122|983    |
// |WOS:000324248800014|Biology,Math & Physics,Biology,Infectious Diseases,Earth Sciences,Infectious Diseases,Biology,Medical Specialties,Infectious Diseases,Medical Specialties,Biology,Medical Specialties,Chemistry,Biotechnology,Math & Physics,Math & Physics,Biology,Infectious Diseases,Chemistry,Earth Sciences,Health Professionals,Biology,Medical Specialties,Earth Sciences,Medical Specialties,Biotechnology,Biology,Biology,Medical Specialties,Chemistry,Biology,Chemistry,Math & Physics,Earth Sciences,Chemistry,Earth Sciences,Earth Sciences,Brain Research,Brain Research,Medical Specialties,Biology,Biotechnology,Math & Physics,Health Professionals,Math & Physics,Medical Specialties,Medical Specialties,Earth Sciences,Medical Specialties,Earth Sciences,Brain Research,Brain Research,Earth Sciences,Infectious Diseases,Chemistry,Infectious Diseases,Electrical Engineering & Computer Science,Medical Specialties,Health Professionals,Brain Research,Chemistry,Chemistry,Medical Specialties,Medical Specialties,Biology,Infectious Diseases,Medical Specialties,Medical Specialties,Chemical, Mechanical, & Civil Engineering,Biology,Infectious Diseases,Medical Specialties,Chemistry,Medical Specialties,Health Professionals,Math & Physics,Medical Specialties,Chemistry,Infectious Diseases,Brain Research,Biotechnology,Medical Specialties|Marine Pollution,Physics; Current Developments,Insect Physiology,Sexually Transmitted Diseases,Paleogeography,Cytogenetics & Genome Mapping,Molecular Ecology,Drug Safety,Gene Therapy,Gut,Applied Genetics,Eye,Surfactants,Microbiology Biotechnology,Geophysical Science,Space Research,Human Evolution,Mutation; DNA Repair,Chemistry & Material Science,Climatology,Applied Physiology; Muscle,Molecular Biochemical Parasitology,Molecular Endocrinology,Atmospheric GeoPhysics,Diabetes Metabolism,Proteomics,Molecular Biological Evolution,Ecology,Radiation Protection,Nanotechnology,Comparative Animal Physiology,Molecular Physics,Optics & Lasers,Quaternary Research,Electro Analytical Chemistry,GeoChemistry,Geology & Tectonics,Psychosis; Schizophrenia,Vision,Stem Cells,Pest Management Science,Genomics & Nucleic Acids,High Energy Physics,Drug Discovery,Astronomy & Astrophysics,Clinical Endocrinology,Human Molecular Genetics,Paleobiology,Cardiovascular,Oceanography,Psychopharmacology,Neurology,Seismology,AntiMicrobial Agents,Pharmaceutical Design,Molecular Cell Biology,Applied Optics,Fertility,Nutrition,Clinical Neurophysiology,Pharmaceutical Research,Inorganic Chemistry,Toxicology Applied Pharmacology,Developmental Biology,Marine Biology,Bacteriology,Pharmacology Science,Kidney,Material Science,Plant Physiology,Virology,Leukemia,Organic Chemistry,Rheumatology,Hospital Financial Management,Surface Science,Oncology,Macromolecules & Polymers,Immunology,Neuroscience; Molecular & Cellular,Protein Science,Clinical Cancer Research|0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122|983    |
// |WOS:000277357100040|Biology,Math & Physics,Biology,Infectious Diseases,Earth Sciences,Infectious Diseases,Biology,Medical Specialties,Infectious Diseases,Medical Specialties,Biology,Medical Specialties,Chemistry,Biotechnology,Math & Physics,Math & Physics,Biology,Infectious Diseases,Chemistry,Earth Sciences,Health Professionals,Biology,Medical Specialties,Earth Sciences,Medical Specialties,Biotechnology,Biology,Biology,Medical Specialties,Chemistry,Biology,Chemistry,Math & Physics,Earth Sciences,Chemistry,Earth Sciences,Earth Sciences,Brain Research,Brain Research,Medical Specialties,Biology,Biotechnology,Math & Physics,Health Professionals,Math & Physics,Medical Specialties,Medical Specialties,Earth Sciences,Medical Specialties,Earth Sciences,Brain Research,Brain Research,Earth Sciences,Infectious Diseases,Chemistry,Infectious Diseases,Electrical Engineering & Computer Science,Medical Specialties,Health Professionals,Brain Research,Chemistry,Chemistry,Medical Specialties,Medical Specialties,Biology,Infectious Diseases,Medical Specialties,Medical Specialties,Chemical, Mechanical, & Civil Engineering,Biology,Infectious Diseases,Medical Specialties,Chemistry,Medical Specialties,Health Professionals,Math & Physics,Medical Specialties,Chemistry,Infectious Diseases,Brain Research,Biotechnology,Medical Specialties|Marine Pollution,Physics; Current Developments,Insect Physiology,Sexually Transmitted Diseases,Paleogeography,Cytogenetics & Genome Mapping,Molecular Ecology,Drug Safety,Gene Therapy,Gut,Applied Genetics,Eye,Surfactants,Microbiology Biotechnology,Geophysical Science,Space Research,Human Evolution,Mutation; DNA Repair,Chemistry & Material Science,Climatology,Applied Physiology; Muscle,Molecular Biochemical Parasitology,Molecular Endocrinology,Atmospheric GeoPhysics,Diabetes Metabolism,Proteomics,Molecular Biological Evolution,Ecology,Radiation Protection,Nanotechnology,Comparative Animal Physiology,Molecular Physics,Optics & Lasers,Quaternary Research,Electro Analytical Chemistry,GeoChemistry,Geology & Tectonics,Psychosis; Schizophrenia,Vision,Stem Cells,Pest Management Science,Genomics & Nucleic Acids,High Energy Physics,Drug Discovery,Astronomy & Astrophysics,Clinical Endocrinology,Human Molecular Genetics,Paleobiology,Cardiovascular,Oceanography,Psychopharmacology,Neurology,Seismology,AntiMicrobial Agents,Pharmaceutical Design,Molecular Cell Biology,Applied Optics,Fertility,Nutrition,Clinical Neurophysiology,Pharmaceutical Research,Inorganic Chemistry,Toxicology Applied Pharmacology,Developmental Biology,Marine Biology,Bacteriology,Pharmacology Science,Kidney,Material Science,Plant Physiology,Virology,Leukemia,Organic Chemistry,Rheumatology,Hospital Financial Management,Surface Science,Oncology,Macromolecules & Polymers,Immunology,Neuroscience; Molecular & Cellular,Protein Science,Clinical Cancer Research|0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122|983    |
// |WOS:000334474500017|Biology,Math & Physics,Biology,Infectious Diseases,Earth Sciences,Infectious Diseases,Biology,Medical Specialties,Infectious Diseases,Medical Specialties,Biology,Medical Specialties,Chemistry,Biotechnology,Math & Physics,Math & Physics,Biology,Infectious Diseases,Chemistry,Earth Sciences,Health Professionals,Biology,Medical Specialties,Earth Sciences,Medical Specialties,Biotechnology,Biology,Biology,Medical Specialties,Chemistry,Biology,Chemistry,Math & Physics,Earth Sciences,Chemistry,Earth Sciences,Earth Sciences,Brain Research,Brain Research,Medical Specialties,Biology,Biotechnology,Math & Physics,Health Professionals,Math & Physics,Medical Specialties,Medical Specialties,Earth Sciences,Medical Specialties,Earth Sciences,Brain Research,Brain Research,Earth Sciences,Infectious Diseases,Chemistry,Infectious Diseases,Electrical Engineering & Computer Science,Medical Specialties,Health Professionals,Brain Research,Chemistry,Chemistry,Medical Specialties,Medical Specialties,Biology,Infectious Diseases,Medical Specialties,Medical Specialties,Chemical, Mechanical, & Civil Engineering,Biology,Infectious Diseases,Medical Specialties,Chemistry,Medical Specialties,Health Professionals,Math & Physics,Medical Specialties,Chemistry,Infectious Diseases,Brain Research,Biotechnology,Medical Specialties|Marine Pollution,Physics; Current Developments,Insect Physiology,Sexually Transmitted Diseases,Paleogeography,Cytogenetics & Genome Mapping,Molecular Ecology,Drug Safety,Gene Therapy,Gut,Applied Genetics,Eye,Surfactants,Microbiology Biotechnology,Geophysical Science,Space Research,Human Evolution,Mutation; DNA Repair,Chemistry & Material Science,Climatology,Applied Physiology; Muscle,Molecular Biochemical Parasitology,Molecular Endocrinology,Atmospheric GeoPhysics,Diabetes Metabolism,Proteomics,Molecular Biological Evolution,Ecology,Radiation Protection,Nanotechnology,Comparative Animal Physiology,Molecular Physics,Optics & Lasers,Quaternary Research,Electro Analytical Chemistry,GeoChemistry,Geology & Tectonics,Psychosis; Schizophrenia,Vision,Stem Cells,Pest Management Science,Genomics & Nucleic Acids,High Energy Physics,Drug Discovery,Astronomy & Astrophysics,Clinical Endocrinology,Human Molecular Genetics,Paleobiology,Cardiovascular,Oceanography,Psychopharmacology,Neurology,Seismology,AntiMicrobial Agents,Pharmaceutical Design,Molecular Cell Biology,Applied Optics,Fertility,Nutrition,Clinical Neurophysiology,Pharmaceutical Research,Inorganic Chemistry,Toxicology Applied Pharmacology,Developmental Biology,Marine Biology,Bacteriology,Pharmacology Science,Kidney,Material Science,Plant Physiology,Virology,Leukemia,Organic Chemistry,Rheumatology,Hospital Financial Management,Surface Science,Oncology,Macromolecules & Polymers,Immunology,Neuroscience; Molecular & Cellular,Protein Science,Clinical Cancer Research|0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122|983    |
// |WOS:000323370600037|Biology,Math & Physics,Biology,Infectious Diseases,Earth Sciences,Infectious Diseases,Biology,Medical Specialties,Infectious Diseases,Medical Specialties,Biology,Medical Specialties,Chemistry,Biotechnology,Math & Physics,Math & Physics,Biology,Infectious Diseases,Chemistry,Earth Sciences,Health Professionals,Biology,Medical Specialties,Earth Sciences,Medical Specialties,Biotechnology,Biology,Biology,Medical Specialties,Chemistry,Biology,Chemistry,Math & Physics,Earth Sciences,Chemistry,Earth Sciences,Earth Sciences,Brain Research,Brain Research,Medical Specialties,Biology,Biotechnology,Math & Physics,Health Professionals,Math & Physics,Medical Specialties,Medical Specialties,Earth Sciences,Medical Specialties,Earth Sciences,Brain Research,Brain Research,Earth Sciences,Infectious Diseases,Chemistry,Infectious Diseases,Electrical Engineering & Computer Science,Medical Specialties,Health Professionals,Brain Research,Chemistry,Chemistry,Medical Specialties,Medical Specialties,Biology,Infectious Diseases,Medical Specialties,Medical Specialties,Chemical, Mechanical, & Civil Engineering,Biology,Infectious Diseases,Medical Specialties,Chemistry,Medical Specialties,Health Professionals,Math & Physics,Medical Specialties,Chemistry,Infectious Diseases,Brain Research,Biotechnology,Medical Specialties|Marine Pollution,Physics; Current Developments,Insect Physiology,Sexually Transmitted Diseases,Paleogeography,Cytogenetics & Genome Mapping,Molecular Ecology,Drug Safety,Gene Therapy,Gut,Applied Genetics,Eye,Surfactants,Microbiology Biotechnology,Geophysical Science,Space Research,Human Evolution,Mutation; DNA Repair,Chemistry & Material Science,Climatology,Applied Physiology; Muscle,Molecular Biochemical Parasitology,Molecular Endocrinology,Atmospheric GeoPhysics,Diabetes Metabolism,Proteomics,Molecular Biological Evolution,Ecology,Radiation Protection,Nanotechnology,Comparative Animal Physiology,Molecular Physics,Optics & Lasers,Quaternary Research,Electro Analytical Chemistry,GeoChemistry,Geology & Tectonics,Psychosis; Schizophrenia,Vision,Stem Cells,Pest Management Science,Genomics & Nucleic Acids,High Energy Physics,Drug Discovery,Astronomy & Astrophysics,Clinical Endocrinology,Human Molecular Genetics,Paleobiology,Cardiovascular,Oceanography,Psychopharmacology,Neurology,Seismology,AntiMicrobial Agents,Pharmaceutical Design,Molecular Cell Biology,Applied Optics,Fertility,Nutrition,Clinical Neurophysiology,Pharmaceutical Research,Inorganic Chemistry,Toxicology Applied Pharmacology,Developmental Biology,Marine Biology,Bacteriology,Pharmacology Science,Kidney,Material Science,Plant Physiology,Virology,Leukemia,Organic Chemistry,Rheumatology,Hospital Financial Management,Surface Science,Oncology,Macromolecules & Polymers,Immunology,Neuroscience; Molecular & Cellular,Protein Science,Clinical Cancer Research|0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122|983    |
// |WOS:000307354500052|Biology,Math & Physics,Biology,Infectious Diseases,Earth Sciences,Infectious Diseases,Biology,Medical Specialties,Infectious Diseases,Medical Specialties,Biology,Medical Specialties,Chemistry,Biotechnology,Math & Physics,Math & Physics,Biology,Infectious Diseases,Chemistry,Earth Sciences,Health Professionals,Biology,Medical Specialties,Earth Sciences,Medical Specialties,Biotechnology,Biology,Biology,Medical Specialties,Chemistry,Biology,Chemistry,Math & Physics,Earth Sciences,Chemistry,Earth Sciences,Earth Sciences,Brain Research,Brain Research,Medical Specialties,Biology,Biotechnology,Math & Physics,Health Professionals,Math & Physics,Medical Specialties,Medical Specialties,Earth Sciences,Medical Specialties,Earth Sciences,Brain Research,Brain Research,Earth Sciences,Infectious Diseases,Chemistry,Infectious Diseases,Electrical Engineering & Computer Science,Medical Specialties,Health Professionals,Brain Research,Chemistry,Chemistry,Medical Specialties,Medical Specialties,Biology,Infectious Diseases,Medical Specialties,Medical Specialties,Chemical, Mechanical, & Civil Engineering,Biology,Infectious Diseases,Medical Specialties,Chemistry,Medical Specialties,Health Professionals,Math & Physics,Medical Specialties,Chemistry,Infectious Diseases,Brain Research,Biotechnology,Medical Specialties|Marine Pollution,Physics; Current Developments,Insect Physiology,Sexually Transmitted Diseases,Paleogeography,Cytogenetics & Genome Mapping,Molecular Ecology,Drug Safety,Gene Therapy,Gut,Applied Genetics,Eye,Surfactants,Microbiology Biotechnology,Geophysical Science,Space Research,Human Evolution,Mutation; DNA Repair,Chemistry & Material Science,Climatology,Applied Physiology; Muscle,Molecular Biochemical Parasitology,Molecular Endocrinology,Atmospheric GeoPhysics,Diabetes Metabolism,Proteomics,Molecular Biological Evolution,Ecology,Radiation Protection,Nanotechnology,Comparative Animal Physiology,Molecular Physics,Optics & Lasers,Quaternary Research,Electro Analytical Chemistry,GeoChemistry,Geology & Tectonics,Psychosis; Schizophrenia,Vision,Stem Cells,Pest Management Science,Genomics & Nucleic Acids,High Energy Physics,Drug Discovery,Astronomy & Astrophysics,Clinical Endocrinology,Human Molecular Genetics,Paleobiology,Cardiovascular,Oceanography,Psychopharmacology,Neurology,Seismology,AntiMicrobial Agents,Pharmaceutical Design,Molecular Cell Biology,Applied Optics,Fertility,Nutrition,Clinical Neurophysiology,Pharmaceutical Research,Inorganic Chemistry,Toxicology Applied Pharmacology,Developmental Biology,Marine Biology,Bacteriology,Pharmacology Science,Kidney,Material Science,Plant Physiology,Virology,Leukemia,Organic Chemistry,Rheumatology,Hospital Financial Management,Surface Science,Oncology,Macromolecules & Polymers,Immunology,Neuroscience; Molecular & Cellular,Protein Science,Clinical Cancer Research|0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122|983    |
// |WOS:000311390600039|Biology,Math & Physics,Biology,Infectious Diseases,Earth Sciences,Infectious Diseases,Biology,Medical Specialties,Infectious Diseases,Medical Specialties,Biology,Medical Specialties,Chemistry,Biotechnology,Math & Physics,Math & Physics,Biology,Infectious Diseases,Chemistry,Earth Sciences,Health Professionals,Biology,Medical Specialties,Earth Sciences,Medical Specialties,Biotechnology,Biology,Biology,Medical Specialties,Chemistry,Biology,Chemistry,Math & Physics,Earth Sciences,Chemistry,Earth Sciences,Earth Sciences,Brain Research,Brain Research,Medical Specialties,Biology,Biotechnology,Math & Physics,Health Professionals,Math & Physics,Medical Specialties,Medical Specialties,Earth Sciences,Medical Specialties,Earth Sciences,Brain Research,Brain Research,Earth Sciences,Infectious Diseases,Chemistry,Infectious Diseases,Electrical Engineering & Computer Science,Medical Specialties,Health Professionals,Brain Research,Chemistry,Chemistry,Medical Specialties,Medical Specialties,Biology,Infectious Diseases,Medical Specialties,Medical Specialties,Chemical, Mechanical, & Civil Engineering,Biology,Infectious Diseases,Medical Specialties,Chemistry,Medical Specialties,Health Professionals,Math & Physics,Medical Specialties,Chemistry,Infectious Diseases,Brain Research,Biotechnology,Medical Specialties|Marine Pollution,Physics; Current Developments,Insect Physiology,Sexually Transmitted Diseases,Paleogeography,Cytogenetics & Genome Mapping,Molecular Ecology,Drug Safety,Gene Therapy,Gut,Applied Genetics,Eye,Surfactants,Microbiology Biotechnology,Geophysical Science,Space Research,Human Evolution,Mutation; DNA Repair,Chemistry & Material Science,Climatology,Applied Physiology; Muscle,Molecular Biochemical Parasitology,Molecular Endocrinology,Atmospheric GeoPhysics,Diabetes Metabolism,Proteomics,Molecular Biological Evolution,Ecology,Radiation Protection,Nanotechnology,Comparative Animal Physiology,Molecular Physics,Optics & Lasers,Quaternary Research,Electro Analytical Chemistry,GeoChemistry,Geology & Tectonics,Psychosis; Schizophrenia,Vision,Stem Cells,Pest Management Science,Genomics & Nucleic Acids,High Energy Physics,Drug Discovery,Astronomy & Astrophysics,Clinical Endocrinology,Human Molecular Genetics,Paleobiology,Cardiovascular,Oceanography,Psychopharmacology,Neurology,Seismology,AntiMicrobial Agents,Pharmaceutical Design,Molecular Cell Biology,Applied Optics,Fertility,Nutrition,Clinical Neurophysiology,Pharmaceutical Research,Inorganic Chemistry,Toxicology Applied Pharmacology,Developmental Biology,Marine Biology,Bacteriology,Pharmacology Science,Kidney,Material Science,Plant Physiology,Virology,Leukemia,Organic Chemistry,Rheumatology,Hospital Financial Management,Surface Science,Oncology,Macromolecules & Polymers,Immunology,Neuroscience; Molecular & Cellular,Protein Science,Clinical Cancer Research|0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122|983    |
// |WOS:000286433100015|Biology,Math & Physics,Biology,Infectious Diseases,Earth Sciences,Infectious Diseases,Biology,Medical Specialties,Infectious Diseases,Medical Specialties,Biology,Medical Specialties,Chemistry,Biotechnology,Math & Physics,Math & Physics,Biology,Infectious Diseases,Chemistry,Earth Sciences,Health Professionals,Biology,Medical Specialties,Earth Sciences,Medical Specialties,Biotechnology,Biology,Biology,Medical Specialties,Chemistry,Biology,Chemistry,Math & Physics,Earth Sciences,Chemistry,Earth Sciences,Earth Sciences,Brain Research,Brain Research,Medical Specialties,Biology,Biotechnology,Math & Physics,Health Professionals,Math & Physics,Medical Specialties,Medical Specialties,Earth Sciences,Medical Specialties,Earth Sciences,Brain Research,Brain Research,Earth Sciences,Infectious Diseases,Chemistry,Infectious Diseases,Electrical Engineering & Computer Science,Medical Specialties,Health Professionals,Brain Research,Chemistry,Chemistry,Medical Specialties,Medical Specialties,Biology,Infectious Diseases,Medical Specialties,Medical Specialties,Chemical, Mechanical, & Civil Engineering,Biology,Infectious Diseases,Medical Specialties,Chemistry,Medical Specialties,Health Professionals,Math & Physics,Medical Specialties,Chemistry,Infectious Diseases,Brain Research,Biotechnology,Medical Specialties|Marine Pollution,Physics; Current Developments,Insect Physiology,Sexually Transmitted Diseases,Paleogeography,Cytogenetics & Genome Mapping,Molecular Ecology,Drug Safety,Gene Therapy,Gut,Applied Genetics,Eye,Surfactants,Microbiology Biotechnology,Geophysical Science,Space Research,Human Evolution,Mutation; DNA Repair,Chemistry & Material Science,Climatology,Applied Physiology; Muscle,Molecular Biochemical Parasitology,Molecular Endocrinology,Atmospheric GeoPhysics,Diabetes Metabolism,Proteomics,Molecular Biological Evolution,Ecology,Radiation Protection,Nanotechnology,Comparative Animal Physiology,Molecular Physics,Optics & Lasers,Quaternary Research,Electro Analytical Chemistry,GeoChemistry,Geology & Tectonics,Psychosis; Schizophrenia,Vision,Stem Cells,Pest Management Science,Genomics & Nucleic Acids,High Energy Physics,Drug Discovery,Astronomy & Astrophysics,Clinical Endocrinology,Human Molecular Genetics,Paleobiology,Cardiovascular,Oceanography,Psychopharmacology,Neurology,Seismology,AntiMicrobial Agents,Pharmaceutical Design,Molecular Cell Biology,Applied Optics,Fertility,Nutrition,Clinical Neurophysiology,Pharmaceutical Research,Inorganic Chemistry,Toxicology Applied Pharmacology,Developmental Biology,Marine Biology,Bacteriology,Pharmacology Science,Kidney,Material Science,Plant Physiology,Virology,Leukemia,Organic Chemistry,Rheumatology,Hospital Financial Management,Surface Science,Oncology,Macromolecules & Polymers,Immunology,Neuroscience; Molecular & Cellular,Protein Science,Clinical Cancer Research|0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122|983    |
// |WOS:000302703900048|Biology,Math & Physics,Biology,Infectious Diseases,Earth Sciences,Infectious Diseases,Biology,Medical Specialties,Infectious Diseases,Medical Specialties,Biology,Medical Specialties,Chemistry,Biotechnology,Math & Physics,Math & Physics,Biology,Infectious Diseases,Chemistry,Earth Sciences,Health Professionals,Biology,Medical Specialties,Earth Sciences,Medical Specialties,Biotechnology,Biology,Biology,Medical Specialties,Chemistry,Biology,Chemistry,Math & Physics,Earth Sciences,Chemistry,Earth Sciences,Earth Sciences,Brain Research,Brain Research,Medical Specialties,Biology,Biotechnology,Math & Physics,Health Professionals,Math & Physics,Medical Specialties,Medical Specialties,Earth Sciences,Medical Specialties,Earth Sciences,Brain Research,Brain Research,Earth Sciences,Infectious Diseases,Chemistry,Infectious Diseases,Electrical Engineering & Computer Science,Medical Specialties,Health Professionals,Brain Research,Chemistry,Chemistry,Medical Specialties,Medical Specialties,Biology,Infectious Diseases,Medical Specialties,Medical Specialties,Chemical, Mechanical, & Civil Engineering,Biology,Infectious Diseases,Medical Specialties,Chemistry,Medical Specialties,Health Professionals,Math & Physics,Medical Specialties,Chemistry,Infectious Diseases,Brain Research,Biotechnology,Medical Specialties|Marine Pollution,Physics; Current Developments,Insect Physiology,Sexually Transmitted Diseases,Paleogeography,Cytogenetics & Genome Mapping,Molecular Ecology,Drug Safety,Gene Therapy,Gut,Applied Genetics,Eye,Surfactants,Microbiology Biotechnology,Geophysical Science,Space Research,Human Evolution,Mutation; DNA Repair,Chemistry & Material Science,Climatology,Applied Physiology; Muscle,Molecular Biochemical Parasitology,Molecular Endocrinology,Atmospheric GeoPhysics,Diabetes Metabolism,Proteomics,Molecular Biological Evolution,Ecology,Radiation Protection,Nanotechnology,Comparative Animal Physiology,Molecular Physics,Optics & Lasers,Quaternary Research,Electro Analytical Chemistry,GeoChemistry,Geology & Tectonics,Psychosis; Schizophrenia,Vision,Stem Cells,Pest Management Science,Genomics & Nucleic Acids,High Energy Physics,Drug Discovery,Astronomy & Astrophysics,Clinical Endocrinology,Human Molecular Genetics,Paleobiology,Cardiovascular,Oceanography,Psychopharmacology,Neurology,Seismology,AntiMicrobial Agents,Pharmaceutical Design,Molecular Cell Biology,Applied Optics,Fertility,Nutrition,Clinical Neurophysiology,Pharmaceutical Research,Inorganic Chemistry,Toxicology Applied Pharmacology,Developmental Biology,Marine Biology,Bacteriology,Pharmacology Science,Kidney,Material Science,Plant Physiology,Virology,Leukemia,Organic Chemistry,Rheumatology,Hospital Financial Management,Surface Science,Oncology,Macromolecules & Polymers,Immunology,Neuroscience; Molecular & Cellular,Protein Science,Clinical Cancer Research|0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122|983    |
// ...
// |WOS:000287971200038|Biology,Math & Physics,Biology,Infectious Diseases,Earth Sciences,Infectious Diseases,Biology,Medical Specialties,Infectious Diseases,Medical Specialties,Biology,Medical Specialties,Chemistry,Biotechnology,Math & Physics,Math & Physics,Biology,Infectious Diseases,Chemistry,Earth Sciences,Health Professionals,Biology,Medical Specialties,Earth Sciences,Medical Specialties,Biotechnology,Biology,Biology,Medical Specialties,Chemistry,Biology,Chemistry,Math & Physics,Earth Sciences,Chemistry,Earth Sciences,Earth Sciences,Brain Research,Brain Research,Medical Specialties,Biology,Biotechnology,Math & Physics,Health Professionals,Math & Physics,Medical Specialties,Medical Specialties,Earth Sciences,Medical Specialties,Earth Sciences,Brain Research,Brain Research,Earth Sciences,Infectious Diseases,Chemistry,Infectious Diseases,Electrical Engineering & Computer Science,Medical Specialties,Health Professionals,Brain Research,Chemistry,Chemistry,Medical Specialties,Medical Specialties,Biology,Infectious Diseases,Medical Specialties,Medical Specialties,Chemical, Mechanical, & Civil Engineering,Biology,Infectious Diseases,Medical Specialties,Chemistry,Medical Specialties,Health Professionals,Math & Physics,Medical Specialties,Chemistry,Infectious Diseases,Brain Research,Biotechnology,Medical Specialties|Marine Pollution,Physics; Current Developments,Insect Physiology,Sexually Transmitted Diseases,Paleogeography,Cytogenetics & Genome Mapping,Molecular Ecology,Drug Safety,Gene Therapy,Gut,Applied Genetics,Eye,Surfactants,Microbiology Biotechnology,Geophysical Science,Space Research,Human Evolution,Mutation; DNA Repair,Chemistry & Material Science,Climatology,Applied Physiology; Muscle,Molecular Biochemical Parasitology,Molecular Endocrinology,Atmospheric GeoPhysics,Diabetes Metabolism,Proteomics,Molecular Biological Evolution,Ecology,Radiation Protection,Nanotechnology,Comparative Animal Physiology,Molecular Physics,Optics & Lasers,Quaternary Research,Electro Analytical Chemistry,GeoChemistry,Geology & Tectonics,Psychosis; Schizophrenia,Vision,Stem Cells,Pest Management Science,Genomics & Nucleic Acids,High Energy Physics,Drug Discovery,Astronomy & Astrophysics,Clinical Endocrinology,Human Molecular Genetics,Paleobiology,Cardiovascular,Oceanography,Psychopharmacology,Neurology,Seismology,AntiMicrobial Agents,Pharmaceutical Design,Molecular Cell Biology,Applied Optics,Fertility,Nutrition,Clinical Neurophysiology,Pharmaceutical Research,Inorganic Chemistry,Toxicology Applied Pharmacology,Developmental Biology,Marine Biology,Bacteriology,Pharmacology Science,Kidney,Material Science,Plant Physiology,Virology,Leukemia,Organic Chemistry,Rheumatology,Hospital Financial Management,Surface Science,Oncology,Macromolecules & Polymers,Immunology,Neuroscience; Molecular & Cellular,Protein Science,Clinical Cancer Research|0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122|983    |
// |WOS:000315149600021|Biology,Math & Physics,Biology,Infectious Diseases,Earth Sciences,Infectious Diseases,Biology,Medical Specialties,Infectious Diseases,Medical Specialties,Biology,Medical Specialties,Chemistry,Biotechnology,Math & Physics,Math & Physics,Biology,Infectious Diseases,Chemistry,Earth Sciences,Health Professionals,Biology,Medical Specialties,Earth Sciences,Medical Specialties,Biotechnology,Biology,Biology,Medical Specialties,Chemistry,Biology,Chemistry,Math & Physics,Earth Sciences,Chemistry,Earth Sciences,Earth Sciences,Brain Research,Brain Research,Medical Specialties,Biology,Biotechnology,Math & Physics,Health Professionals,Math & Physics,Medical Specialties,Medical Specialties,Earth Sciences,Medical Specialties,Earth Sciences,Brain Research,Brain Research,Earth Sciences,Infectious Diseases,Chemistry,Infectious Diseases,Electrical Engineering & Computer Science,Medical Specialties,Health Professionals,Brain Research,Chemistry,Chemistry,Medical Specialties,Medical Specialties,Biology,Infectious Diseases,Medical Specialties,Medical Specialties,Chemical, Mechanical, & Civil Engineering,Biology,Infectious Diseases,Medical Specialties,Chemistry,Medical Specialties,Health Professionals,Math & Physics,Medical Specialties,Chemistry,Infectious Diseases,Brain Research,Biotechnology,Medical Specialties|Marine Pollution,Physics; Current Developments,Insect Physiology,Sexually Transmitted Diseases,Paleogeography,Cytogenetics & Genome Mapping,Molecular Ecology,Drug Safety,Gene Therapy,Gut,Applied Genetics,Eye,Surfactants,Microbiology Biotechnology,Geophysical Science,Space Research,Human Evolution,Mutation; DNA Repair,Chemistry & Material Science,Climatology,Applied Physiology; Muscle,Molecular Biochemical Parasitology,Molecular Endocrinology,Atmospheric GeoPhysics,Diabetes Metabolism,Proteomics,Molecular Biological Evolution,Ecology,Radiation Protection,Nanotechnology,Comparative Animal Physiology,Molecular Physics,Optics & Lasers,Quaternary Research,Electro Analytical Chemistry,GeoChemistry,Geology & Tectonics,Psychosis; Schizophrenia,Vision,Stem Cells,Pest Management Science,Genomics & Nucleic Acids,High Energy Physics,Drug Discovery,Astronomy & Astrophysics,Clinical Endocrinology,Human Molecular Genetics,Paleobiology,Cardiovascular,Oceanography,Psychopharmacology,Neurology,Seismology,AntiMicrobial Agents,Pharmaceutical Design,Molecular Cell Biology,Applied Optics,Fertility,Nutrition,Clinical Neurophysiology,Pharmaceutical Research,Inorganic Chemistry,Toxicology Applied Pharmacology,Developmental Biology,Marine Biology,Bacteriology,Pharmacology Science,Kidney,Material Science,Plant Physiology,Virology,Leukemia,Organic Chemistry,Rheumatology,Hospital Financial Management,Surface Science,Oncology,Macromolecules & Polymers,Immunology,Neuroscience; Molecular & Cellular,Protein Science,Clinical Cancer Research|0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122|983    |
// |WOS:000316053400040|Biology,Math & Physics,Biology,Infectious Diseases,Earth Sciences,Infectious Diseases,Biology,Medical Specialties,Infectious Diseases,Medical Specialties,Biology,Medical Specialties,Chemistry,Biotechnology,Math & Physics,Math & Physics,Biology,Infectious Diseases,Chemistry,Earth Sciences,Health Professionals,Biology,Medical Specialties,Earth Sciences,Medical Specialties,Biotechnology,Biology,Biology,Medical Specialties,Chemistry,Biology,Chemistry,Math & Physics,Earth Sciences,Chemistry,Earth Sciences,Earth Sciences,Brain Research,Brain Research,Medical Specialties,Biology,Biotechnology,Math & Physics,Health Professionals,Math & Physics,Medical Specialties,Medical Specialties,Earth Sciences,Medical Specialties,Earth Sciences,Brain Research,Brain Research,Earth Sciences,Infectious Diseases,Chemistry,Infectious Diseases,Electrical Engineering & Computer Science,Medical Specialties,Health Professionals,Brain Research,Chemistry,Chemistry,Medical Specialties,Medical Specialties,Biology,Infectious Diseases,Medical Specialties,Medical Specialties,Chemical, Mechanical, & Civil Engineering,Biology,Infectious Diseases,Medical Specialties,Chemistry,Medical Specialties,Health Professionals,Math & Physics,Medical Specialties,Chemistry,Infectious Diseases,Brain Research,Biotechnology,Medical Specialties|Marine Pollution,Physics; Current Developments,Insect Physiology,Sexually Transmitted Diseases,Paleogeography,Cytogenetics & Genome Mapping,Molecular Ecology,Drug Safety,Gene Therapy,Gut,Applied Genetics,Eye,Surfactants,Microbiology Biotechnology,Geophysical Science,Space Research,Human Evolution,Mutation; DNA Repair,Chemistry & Material Science,Climatology,Applied Physiology; Muscle,Molecular Biochemical Parasitology,Molecular Endocrinology,Atmospheric GeoPhysics,Diabetes Metabolism,Proteomics,Molecular Biological Evolution,Ecology,Radiation Protection,Nanotechnology,Comparative Animal Physiology,Molecular Physics,Optics & Lasers,Quaternary Research,Electro Analytical Chemistry,GeoChemistry,Geology & Tectonics,Psychosis; Schizophrenia,Vision,Stem Cells,Pest Management Science,Genomics & Nucleic Acids,High Energy Physics,Drug Discovery,Astronomy & Astrophysics,Clinical Endocrinology,Human Molecular Genetics,Paleobiology,Cardiovascular,Oceanography,Psychopharmacology,Neurology,Seismology,AntiMicrobial Agents,Pharmaceutical Design,Molecular Cell Biology,Applied Optics,Fertility,Nutrition,Clinical Neurophysiology,Pharmaceutical Research,Inorganic Chemistry,Toxicology Applied Pharmacology,Developmental Biology,Marine Biology,Bacteriology,Pharmacology Science,Kidney,Material Science,Plant Physiology,Virology,Leukemia,Organic Chemistry,Rheumatology,Hospital Financial Management,Surface Science,Oncology,Macromolecules & Polymers,Immunology,Neuroscience; Molecular & Cellular,Protein Science,Clinical Cancer Research|0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122,0.012195122|983    |
// +-------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
// only showing top 60 rows
// UCSDmap = [wosid: string, disciplines: string ... 2 more fields]
// [wosid: string, disciplines: string ... 2 more fields]

// %%
val papers7 = papers3.join(UCSDmap, papers3("UID")===UCSDmap("wosid"), "left")
papers7.describe().filter($"summary" === "count").show
// Out:
// +-------+-------+-------+-------+--------+-----------+-------+-------+--------+------------+-----------+-------+-----------+--------------+---------+
// |summary|    _c0|    UID|journal|headings|subheadings|     WC|     SC|journ_id|journal_name|source_type|  wosid|disciplines|subdisciplines|fractions|
// +-------+-------+-------+-------+--------+-----------+-------+-------+--------+------------+-----------+-------+-----------+--------------+---------+
// |  count|9686604|9686604|9686604| 9584480|    8030289|9584480|9584480| 6369116|     6369116|    6369116|9686604|    9686604|       9686604|  9686604|
// +-------+-------+-------+-------+--------+-----------+-------+-------+--------+------------+-----------+-------+-----------+--------------+---------+
// papers7 = [_c0: string, UID: string ... 15 more fields]
// lastException: Throwable = null
// [_c0: string, UID: string ... 15 more fields]

// %%
papers7.printSchema()
// Out:
// root
//  |-- _c0: string (nullable = true)
//  |-- UID: string (nullable = true)
//  |-- journal: string (nullable = true)
//  |-- heading: array (nullable = true)
//  |    |-- element: string (containsNull = true)
//  |-- subheading: array (nullable = true)
//  |    |-- element: string (containsNull = true)
//  |-- subject: array (nullable = true)
//  |    |-- element: struct (containsNull = true)
//  |    |    |-- _VALUE: string (nullable = true)
//  |    |    |-- _ascatype: string (nullable = true)
//  |-- headings: string (nullable = true)
//  |-- subheadings: string (nullable = true)
//  |-- WC: string (nullable = true)
//  |-- SC: string (nullable = true)
//  |-- journ_id: string (nullable = true)
//  |-- journal_name: string (nullable = true)
//  |-- source_type: string (nullable = true)
//  |-- wosid: string (nullable = true)
//  |-- disciplines: string (nullable = true)
//  |-- subdisciplines: string (nullable = true)
//  |-- fractions: string (nullable = true)

// %%
papers7.select("wosid","headings","subheadings","WC","SC","disciplines","subdisciplines","fractions")
.coalesce(1).write.mode(SaveMode.Overwrite)
    .format("com.databricks.spark.csv")
    .option("header", "true")
    .save("wasbs://mag-2020-02-14@iunimag.blob.core.windows.net/processed_data.csv")
